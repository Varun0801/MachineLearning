# %% [markdown]
# <a href="https://colab.research.google.com/github/Varun0801/MachineLearning/blob/master/Linear_Regression_CompanyProfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/Profit-Dataset - Sheet1.csv')
data = pd.DataFrame(data)
data
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
data.shape
# Out:
# (46, 4)

# %%
features = data.iloc[:,:3]
target = data.iloc[:,3]
print(features.shape)
print(target.shape)
features
# Out:
# (46, 3)
# (46,)
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split, cross_val_score

# %%
model = linear_model.LinearRegression()
X_train,X_test,y_train,y_test = train_test_split(features,target,test_size=0.2)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (36, 3)
# (36,)
# (10, 3)
# (10,)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [ 0.75956262 -0.07160966  0.02023242]
# 61689.11147578683

# %%
predictions = list(model.predict(X_test))
predictions
# Out:
# [103603.97074746445,
#  183333.2898583491,
#  187024.31192370618,
#  98975.95540074448,
#  88575.05424224751,
#  155981.14142984603,
#  117585.7546679193,
#  156790.15090103194,
#  115237.06475683776,
#  114448.77509189775]

# %%
true_values = list(y_test)
true_values
# Out:
# [107404.34,
#  191792.06,
#  192261.83,
#  97483.56,
#  81005.76,
#  156122.51,
#  126992.93,
#  155752.6,
#  110352.25,
#  105008.31]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})
df
# Out:
#        Actual      Predicted
# 24  107404.34  103603.970747
# 1   191792.06  183333.289858
# 0   192261.83  187024.311924
# 30   97483.56   98975.955401
# 38   81005.76   88575.054242
# 6   156122.51  155981.141430
# 16  126992.93  117585.754668
# 7   155752.60  156790.150901
# 21  110352.25  115237.064757
# 26  105008.31  114448.775092

# %%
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 

df.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 5146.972176547437
# Mean Squared Error: 37552189.47556184
# Root Mean Squared Error: 6127.984128207403
